# %%
import pandas as pd

# %%
df = pd.read_excel(r"D:\Documents\pandas\pandas_raw_data\Customer Call List.xlsx")
#Removing duplicates
#Standardization
#Remove null values
#Remove any coloumn

# %%
df = df.drop_duplicates()
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df =df.drop(columns = "Not_Useful_Column")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df['Last_Name'].str.lstrip("....") #comp
# Out:
# 0         Baggins
# 1           Nadir
# 2          /White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11         Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# Name: Last_Name, dtype: object

# %%
df["Last_Name"].str.strip("123._/")
df["Last_Name"] = df["Last_Name"].str.strip("123._/")
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
#df["Phone_Number"].str.replace('[^a-zA-Z0-9]','') #to conver into string then apply lambda

# %%
#str(df["Phone_Number"])
#df["Phone_Number"].apply(lambda x: str(x))  #apply to df
#df["Phone_Number"] = df["Phone_Number"].apply(lambda x: str(x))

# %%
df["Phone_Number"]= df["Phone_Number"].str.replace('/','')
df["Phone_Number"]= df["Phone_Number"].str.replace('|',"")

# %%
df["Phone_Number"]= df["Phone_Number"].apply(lambda x: str(x))

# %%
#df["Phone_Number"].apply(lambda x: x[0:3] + '-' + x[3:6] + '-' + x[6:10])

# %%
df["Phone_Number"]= df["Phone_Number"].replace('nan','') #replacing nan to empty ''
df["Phone_Number"]= df["Phone_Number"].replace('Na','') #replacing Na to empty

# %%
df["Phone_Number"] =df["Phone_Number"].str.replace('-','') #first remove all '-' in the Phone number

# %%
df["Phone_Number"].apply(lambda x: x[0:3] + '-' + x[3:6] + '-' + x[6:10])
df["Phone_Number"] = df["Phone_Number"].apply(lambda x: x[0:3] + '-' + x[3:6] + '-' + x[6:10]) #apply lambda underscores between index = 3,7

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White            --
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger            --
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN            --
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee            --
# 11        1012      Harry      Potter            --
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# ...

# %%
#split the address and state

# %%
df[["Street_Address","State","Zip_Code"]] =df["Address"].str.split(',', expand=True)

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White            --
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger            --
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN            --
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee            --
# 11        1012      Harry      Potter            --
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# ...

# %%
#replace y into Yes and No into N

# %%
df["Paying Customer"] =df["Paying Customer"].str.replace('Yes','Y')

# %%
df["Paying Customer"].str.replace('Y','Yes')
df["Paying Customer"] =df["Paying Customer"].str.replace('Yes','Y')

# %%
df["Paying Customer"].str.replace('No','N')
df["Paying Customer"] = df["Paying Customer"].str.replace('No','N')

# %%
df["Paying Customer"].str.replace('N/a','N')
df["Paying Customer"] =df["Paying Customer"].str.replace('N/a','N')

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White            --
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger            --
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN            --
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee            --
# 11        1012      Harry      Potter            --
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# ...

# %%
df["Do_Not_Contact"].str.replace('Yes','Y')
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace('Yes','Y')

# %%
df["Do_Not_Contact"].str.replace('No','N')
df["Do_Not_Contact"] = df["Do_Not_Contact"].str.replace('No','N')

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White            --
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger            --
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN            --
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee            --
# 11        1012      Harry      Potter            --
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# ...

# %%
df.fillna('')
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White            --
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger            --
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf                        --
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee            --
# 11        1012      Harry      Potter            --
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# ...

# %%
df =df.fillna('')

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White            --
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger            --
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf                        --
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee            --
# 11        1012      Harry      Potter            --
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# ...

# %%
for x in df.index:
    if df.loc[x, "Do_Not_Contact"]=='Y':
        df.drop(x, inplace=True)
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 2         1003     Walter       White            --
# 4         1005        Jon        Snow  876-678-3469
# 6         1007       Jeff      Winger            --
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf                        --
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee            --
# 11        1012      Harry      Potter            --
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent            --
# 19        1020     Anakin   Skywalker  876-678-3469
#
#                            Address Paying Customer Do_Not_Contact  \
# ...

# %%
for x in df.index:
    if df.loc[x, "Do_Not_Contact"]=='':
        df.drop(x, inplace=True)
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 4         1005        Jon        Snow  876-678-3469
# 6         1007       Jeff      Winger            --
# 7         1008   Sherlock      Holmes  876-678-3469
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee            --
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 19        1020     Anakin   Skywalker  876-678-3469
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire               Y              N
# 4                 123 Dragons Road               Y              N
# 6                1209 South Street               N              N
# ...

# %%
#now reset_index
df.reset_index()
# Out:
#     index  CustomerID First_Name   Last_Name  Phone_Number  \
# 0       0        1001      Frodo     Baggins  123-545-5421
# 1       4        1005        Jon        Snow  876-678-3469
# 2       6        1007       Jeff      Winger            --
# 3       7        1008   Sherlock      Holmes  876-678-3469
# 4       9        1010      Peter      Parker  123-545-5421
# 5      10        1011    Samwise      Gamgee            --
# 6      12        1013        Don      Draper  123-543-2345
# 7      13        1014     Leslie       Knope  876-678-3469
# 8      14        1015       Toby  Flenderson  304-762-2467
# 9      15        1016        Ron     Weasley  123-545-5421
# 10     16        1017   Michael        Scott  123-643-9775
# 11     19        1020     Anakin   Skywalker  876-678-3469
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire               Y              N
# ...

# %%
df.reset_index(drop=True)
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1005        Jon        Snow  876-678-3469
# 2         1007       Jeff      Winger            --
# 3         1008   Sherlock      Holmes  876-678-3469
# 4         1010      Peter      Parker  123-545-5421
# 5         1011    Samwise      Gamgee            --
# 6         1013        Don      Draper  123-543-2345
# 7         1014     Leslie       Knope  876-678-3469
# 8         1015       Toby  Flenderson  304-762-2467
# 9         1016        Ron     Weasley  123-545-5421
# 10        1017   Michael        Scott  123-643-9775
# 11        1020     Anakin   Skywalker  876-678-3469
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire               Y              N
# 1                 123 Dragons Road               Y              N
# 2                1209 South Street               N              N
# ...

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 4         1005        Jon        Snow  876-678-3469
# 6         1007       Jeff      Winger            --
# 7         1008   Sherlock      Holmes  876-678-3469
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee            --
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 19        1020     Anakin   Skywalker  876-678-3469
#
#                            Address Paying Customer Do_Not_Contact  \
# 0            123 Shire Lane, Shire               Y              N
# 4                 123 Dragons Road               Y              N
# 6                1209 South Street               N              N
# ...

# %%
invalid_idx = df[df['Phone_Number'].isin(['--', '', None])].index
df = df.drop(invalid_idx)

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#    CustomerID First_Name   Last_Name  Phone_Number  \
# 0        1001      Frodo     Baggins  123-545-5421
# 1        1005        Jon        Snow  876-678-3469
# 2        1008   Sherlock      Holmes  876-678-3469
# 3        1010      Peter      Parker  123-545-5421
# 4        1013        Don      Draper  123-543-2345
# 5        1014     Leslie       Knope  876-678-3469
# 6        1015       Toby  Flenderson  304-762-2467
# 7        1016        Ron     Weasley  123-545-5421
# 8        1017   Michael        Scott  123-643-9775
# 9        1020     Anakin   Skywalker  876-678-3469
#
#                           Address Paying Customer Do_Not_Contact  \
# 0           123 Shire Lane, Shire               Y              N
# 1                123 Dragons Road               Y              N
# 2                   98 Clue Drive               N              N
# 3      25th Main Street, New York               Y              N
# 4                2039 Main Street               Y              N
# ...
