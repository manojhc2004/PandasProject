# %%
import pandas as pd

# %%
#import 
df = pd.read_csv(r"D:\Documents\pandas\pandas_raw_data\student_admission_record_dirty.csv")
df.drop_duplicates()
# Out:
#          Name   Age  Gender  Admission Test Score  High School Percentage  \
# 0     Shehroz  24.0  Female                  50.0                   68.90
# 1       Waqar  21.0  Female                  99.0                   60.73
# 2      Bushra  17.0    Male                  89.0                     NaN
# 3       Aliya  17.0    Male                  55.0                   85.29
# 4       Bilal  20.0    Male                  65.0                   61.13
# 5     Murtaza  23.0  Female                   NaN                     NaN
# 6        Asad  18.0    Male                   NaN                   97.31
# 7       Rabia  20.0  Female                  82.0                   55.67
# 8      Rohail  17.0    Male                  64.0                     NaN
# 9      Kamran  18.0    Male                  53.0                   98.98
# 10     Shafiq  17.0    Male                  78.0                  -10.00
# 11     Nashit  18.0    Male                  89.0                     NaN
# ...

# %%
remove_negative_ages =df[df['Age'] >= 16]
remove_negative_ages
# Out:
#          Name   Age  Gender  Admission Test Score  High School Percentage  \
# 0     Shehroz  24.0  Female                  50.0                   68.90
# 1       Waqar  21.0  Female                  99.0                   60.73
# 2      Bushra  17.0    Male                  89.0                     NaN
# 3       Aliya  17.0    Male                  55.0                   85.29
# 4       Bilal  20.0    Male                  65.0                   61.13
# 5     Murtaza  23.0  Female                   NaN                     NaN
# 6        Asad  18.0    Male                   NaN                   97.31
# 7       Rabia  20.0  Female                  82.0                   55.67
# 8      Rohail  17.0    Male                  64.0                     NaN
# 9      Kamran  18.0    Male                  53.0                   98.98
# 10     Shafiq  17.0    Male                  78.0                  -10.00
# 11     Nashit  18.0    Male                  89.0                     NaN
# ...

# %%
#remove negative ages
df = remove_negative_ages
df
# Out:
#          Name   Age  Gender  Admission Test Score  High School Percentage  \
# 0     Shehroz  24.0  Female                  50.0                   68.90
# 1       Waqar  21.0  Female                  99.0                   60.73
# 2      Bushra  17.0    Male                  89.0                     NaN
# 3       Aliya  17.0    Male                  55.0                   85.29
# 4       Bilal  20.0    Male                  65.0                   61.13
# 5     Murtaza  23.0  Female                   NaN                     NaN
# 6        Asad  18.0    Male                   NaN                   97.31
# 7       Rabia  20.0  Female                  82.0                   55.67
# 8      Rohail  17.0    Male                  64.0                     NaN
# 9      Kamran  18.0    Male                  53.0                   98.98
# 10     Shafiq  17.0    Male                  78.0                  -10.00
# 11     Nashit  18.0    Male                  89.0                     NaN
# ...

# %%
df[df['Admission Test Score'] > 30]
df = df[df['Admission Test Score'] > 30]
df
# Out:
#          Name   Age  Gender  Admission Test Score  High School Percentage  \
# 0     Shehroz  24.0  Female                  50.0                   68.90
# 1       Waqar  21.0  Female                  99.0                   60.73
# 2      Bushra  17.0    Male                  89.0                     NaN
# 3       Aliya  17.0    Male                  55.0                   85.29
# 4       Bilal  20.0    Male                  65.0                   61.13
# 7       Rabia  20.0  Female                  82.0                   55.67
# 8      Rohail  17.0    Male                  64.0                     NaN
# 9      Kamran  18.0    Male                  53.0                   98.98
# 10     Shafiq  17.0    Male                  78.0                  -10.00
# 11     Nashit  18.0    Male                  89.0                     NaN
# 12        NaN  19.0    Male                  66.0                   88.17
# 13      Ahmed  21.0    Male                  62.0                   79.03
# ...

# %%
#now remove High School Percentage	how got below 33%
below_55 = df[df['High School Percentage'] > 33]
df = df[df['High School Percentage'] > 33]
df
# Out:
#          Name   Age  Gender  Admission Test Score  High School Percentage  \
# 0     Shehroz  24.0  Female                  50.0                   68.90
# 1       Waqar  21.0  Female                  99.0                   60.73
# 3       Aliya  17.0    Male                  55.0                   85.29
# 4       Bilal  20.0    Male                  65.0                   61.13
# 7       Rabia  20.0  Female                  82.0                   55.67
# 9      Kamran  18.0    Male                  53.0                   98.98
# 12        NaN  19.0    Male                  66.0                   88.17
# 13      Ahmed  21.0    Male                  62.0                   79.03
# 14    Fareeha  22.0    Male                  86.0                   50.77
# 15       Saim  19.0    Male                  84.0                   97.19
# 17       Uzma  17.0  Female                  96.0                   93.34
# 18     Maryam  19.0  Female                  74.0                   70.26
# ...

# %%
#remove whos studens marks is greater then 100
greater_then_100 = df[df['High School Percentage'] <= 100]
df = df[df['High School Percentage'] <= 100]
df
# Out:
#          Name   Age  Gender  Admission Test Score  High School Percentage  \
# 0     Shehroz  24.0  Female                  50.0                   68.90
# 1       Waqar  21.0  Female                  99.0                   60.73
# 3       Aliya  17.0    Male                  55.0                   85.29
# 4       Bilal  20.0    Male                  65.0                   61.13
# 7       Rabia  20.0  Female                  82.0                   55.67
# 9      Kamran  18.0    Male                  53.0                   98.98
# 12        NaN  19.0    Male                  66.0                   88.17
# 13      Ahmed  21.0    Male                  62.0                   79.03
# 14    Fareeha  22.0    Male                  86.0                   50.77
# 15       Saim  19.0    Male                  84.0                   97.19
# 17       Uzma  17.0  Female                  96.0                   93.34
# 18     Maryam  19.0  Female                  74.0                   70.26
# ...

# %%
#now select only accepted students
accepted  = df[df['Admission Status']=="Accepted"]

df = df[df['Admission Status']=="Accepted"]

# %%
df
# Out:
#          Name   Age Gender  Admission Test Score  High School Percentage  \
# 7       Rabia  20.0      F                  82.0                   55.67
# 13      Ahmed  21.0   Male                  62.0                   79.03
# 18     Maryam  19.0      F                  74.0                   70.26
# 28     Bushra  17.0   Male                  89.0                   78.57
# 35     Feroze  23.0      F                  51.0                   92.36
# 39      Aliya  23.0   Male                  50.0                   85.25
# 42    Wajeeha  21.0   Male                  63.0                   74.83
# 43      Waqar  21.0      F                  99.0                   60.73
# 44      Maham  19.0      F                  52.0                   78.67
# 46    Mehwish  24.0      F                  84.0                   94.33
# 52      Ahmed  21.0   Male                  62.0                   79.03
# 55       Sara  19.0   Male                  68.0                   93.16
# ...

# %%
#Now replace Male as M and Female as F
male_to_m = df['Gender'].replace('Male','M')
df['Gender'] = df['Gender'].replace('Male','M')
female_to_f = df['Gender'].replace('Female','F')
df['Gender'] = df['Gender'].replace('Female','F')
df
# Out:
# C:\Users\manoj\AppData\Local\Temp\ipykernel_2208\621524051.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'] = df['Gender'].replace('Male','M')
# C:\Users\manoj\AppData\Local\Temp\ipykernel_2208\621524051.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'] = df['Gender'].replace('Female','F')
#          Name   Age Gender  Admission Test Score  High School Percentage  \
# 7       Rabia  20.0      F                  82.0                   55.67
# ...

# %%
#now remove Nan values
remove = df.dropna()
df = df.dropna()

# %%
df
# Out:
#          Name   Age Gender  Admission Test Score  High School Percentage  \
# 7       Rabia  20.0      F                  82.0                   55.67
# 13      Ahmed  21.0      M                  62.0                   79.03
# 18     Maryam  19.0      F                  74.0                   70.26
# 28     Bushra  17.0      M                  89.0                   78.57
# 39      Aliya  23.0      M                  50.0                   85.25
# 42    Wajeeha  21.0      M                  63.0                   74.83
# 43      Waqar  21.0      F                  99.0                   60.73
# 44      Maham  19.0      F                  52.0                   78.67
# 46    Mehwish  24.0      F                  84.0                   94.33
# 52      Ahmed  21.0      M                  62.0                   79.03
# 55       Sara  19.0      M                  68.0                   93.16
# 56       Zara  18.0      M                  52.0                   91.02
# ...

# %%
#set index
df = df.reset_index()

# %%
df
# Out:
#     index      Name   Age Gender  Admission Test Score  \
# 0       7     Rabia  20.0      F                  82.0
# 1      13     Ahmed  21.0      M                  62.0
# 2      18    Maryam  19.0      F                  74.0
# 3      28    Bushra  17.0      M                  89.0
# 4      39     Aliya  23.0      M                  50.0
# 5      42   Wajeeha  21.0      M                  63.0
# 6      43     Waqar  21.0      F                  99.0
# 7      44     Maham  19.0      F                  52.0
# 8      46   Mehwish  24.0      F                  84.0
# 9      52     Ahmed  21.0      M                  62.0
# 10     55      Sara  19.0      M                  68.0
# 11     56      Zara  18.0      M                  52.0
# 12     58     Adeel  20.0      F                  70.0
# 13     60    Rohail  19.0      F                  54.0
# 14     61     Hamza  22.0      M                  99.0
# 15     62     Fahad  23.0      M                  93.0
# ...

# %%
#remove old index
df.drop(columns='index', inplace=True)

# %%
df
# Out:
#         Name   Age Gender  Admission Test Score  High School Percentage  \
# 0      Rabia  20.0      F                  82.0                   55.67
# 1      Ahmed  21.0      M                  62.0                   79.03
# 2     Maryam  19.0      F                  74.0                   70.26
# 3     Bushra  17.0      M                  89.0                   78.57
# 4      Aliya  23.0      M                  50.0                   85.25
# 5    Wajeeha  21.0      M                  63.0                   74.83
# 6      Waqar  21.0      F                  99.0                   60.73
# 7      Maham  19.0      F                  52.0                   78.67
# 8    Mehwish  24.0      F                  84.0                   94.33
# 9      Ahmed  21.0      M                  62.0                   79.03
# 10      Sara  19.0      M                  68.0                   93.16
# 11      Zara  18.0      M                  52.0                   91.02
# ...

# %%
df.isnull().sum()
# Out:
# Name                      0
# Age                       0
# Gender                    0
# Admission Test Score      0
# High School Percentage    0
# City                      0
# Admission Status          0
# dtype: int64

# %%
#final
df
# Out:
#         Name   Age Gender  Admission Test Score  High School Percentage  \
# 0      Rabia  20.0      F                  82.0                   55.67
# 1      Ahmed  21.0      M                  62.0                   79.03
# 2     Maryam  19.0      F                  74.0                   70.26
# 3     Bushra  17.0      M                  89.0                   78.57
# 4      Aliya  23.0      M                  50.0                   85.25
# 5    Wajeeha  21.0      M                  63.0                   74.83
# 6      Waqar  21.0      F                  99.0                   60.73
# 7      Maham  19.0      F                  52.0                   78.67
# 8    Mehwish  24.0      F                  84.0                   94.33
# 9      Ahmed  21.0      M                  62.0                   79.03
# 10      Sara  19.0      M                  68.0                   93.16
# 11      Zara  18.0      M                  52.0                   91.02
# ...

# %%
#saving file type as csv
df.to_csv("student_admission_records_cleaned.csv", index=False)
