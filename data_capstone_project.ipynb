# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"Countries.csv")

# %%
df.head()
# Out:
#        country                             country_long        currency  \
# 0  Afghanistan             Islamic State of Afghanistan  Afghan afghani
# 1      Albania                      Republic of Albania    Albanian lek
# 2      Algeria  People's Democratic Republic of Algeria  Algerian dinar
# 3      Andorra                  Principality of Andorra            Euro
# 4       Angola              People's Republic of Angola  Angolan kwanza
#
#        capital_city           region continent   demonym  latitude  longitude  \
# 0             Kabul    Southern Asia      Asia    Afghan      33.0       65.0
# 1            Tirana  Southern Europe    Europe  Albanian      41.0       20.0
# 2           Algiers  Northern Africa    Africa  Algerian      28.0        3.0
# 3  Andorra la Vella  Southern Europe    Europe  Andorran      42.5        1.5
# 4            Luanda    Middle Africa    Africa   Angolan     -12.5       18.5
#
#    agricultural_land  ...  population  women_parliament_seats_pct  \
# 0           383560.0  ...    41128771                    27.01610
# 1            11655.5  ...     2775634                    35.71430
# 2           413588.0  ...    44903225                     8.10811
# 3              187.2  ...       79824                    46.42860
# 4           569525.0  ...    35588987                    33.63640
#
#    rural_population  urban_population  press  democracy_score  democracy_type  \
# 0          30181937          10946834   2.14             2.97   Authoritarian
# 1           1004807           1770827   2.62             5.98   Hybrid regime
# 2          11328186          33575039   1.71             3.50   Authoritarian
# 3              9730             70094   3.17             0.00         Unknown
# 4          11359649          24229338   2.24             3.62   Authoritarian
#
#    median_age      political_leader               title
# 0        12.9          Ashraf Ghani           President
# 1        33.7              Edi Rama      Prime Minister
# 2        24.0  Abdelmadjid Tebboune           President
# 3        38.9   Xavier Espot Zamora  Head of Government
# 4        12.4         João Lourenço           President
#
# [5 rows x 64 columns]

# %%
df.shape
# Out:
# (194, 64)

# %%
df.info()

# %%
df.isna()
# Out:
#      country  country_long  currency  capital_city  region  continent  \
# 0      False         False     False         False   False      False
# 1      False         False     False         False   False      False
# 2      False         False     False         False   False      False
# 3      False         False     False         False   False      False
# 4      False         False     False         False   False      False
# ..       ...           ...       ...           ...     ...        ...
# 189    False         False     False         False   False      False
# 190    False         False     False         False   False      False
# 191    False         False     False         False   False      False
# 192    False         False     False         False   False      False
# 193    False         False     False         False   False      False
#
#      demonym  latitude  longitude  agricultural_land  ...  population  \
# 0      False     False      False              False  ...       False
# 1      False     False      False              False  ...       False
# 2      False     False      False              False  ...       False
# 3      False     False      False              False  ...       False
# 4      False     False      False              False  ...       False
# ..       ...       ...        ...                ...  ...         ...
# 189    False     False      False              False  ...       False
# 190    False     False      False              False  ...       False
# 191    False     False      False              False  ...       False
# 192    False     False      False              False  ...       False
# 193    False     False      False              False  ...       False
#
#      women_parliament_seats_pct  rural_population  urban_population  press  \
# 0                         False             False             False  False
# 1                         False             False             False  False
# 2                         False             False             False  False
# 3                         False             False             False  False
# 4                         False             False             False  False
# ..                          ...               ...               ...    ...
# 189                       False             False             False  False
# 190                        True             False             False  False
# 191                       False             False             False  False
# 192                       False             False             False  False
# 193                       False             False             False  False
#
#      democracy_score  democracy_type  median_age  political_leader  title
# 0              False           False       False             False  False
# 1              False           False       False             False  False
# 2              False           False       False             False  False
# 3              False           False       False             False  False
# 4              False           False       False             False  False
# ..               ...             ...         ...               ...    ...
# 189            False           False       False             False  False
# 190            False           False       False              True   True
# 191            False           False       False             False  False
# 192            False           False       False             False  False
# 193            False           False       False             False  False
#
# [194 rows x 64 columns]

# %%
#which country has the highest population
df[df['population'] == df['population'].max()] # and aslo add ['country']
# Out:
#    country       country_long      currency capital_city         region  \
# 75   India  Republic of India  Indian rupee    New Delhi  Southern Asia
#
#    continent demonym  latitude  longitude  agricultural_land  ...  population  \
# 75      Asia  Indian      20.0       77.0          1790450.0  ...  1417173173
#
#     women_parliament_seats_pct  rural_population  urban_population  press  \
# 75                     14.9446         908804812         508368361   1.71
#
#     democracy_score    democracy_type  median_age  political_leader  \
# 75             7.23  Flawed democracy        23.9     Narendra Modi
#
#              title
# 75  Prime Minister
#
# [1 rows x 64 columns]

# %%
#what is the capital of the country with highest population

df.columns

# %%
df[df['population'] == df['population'].max()]['capital_city']
# Out:
# 75    New Delhi
# Name: capital_city, dtype: object

# %%
#which country has the least populationabs
df[df['population'] == df['population'].min()]['country']
# Out:
# 179    Tuvalu
# Name: country, dtype: object

# %%
#what is teh capital of the country with least population
df[df['population'] == df['population'].min()]['capital_city']
# Out:
# 179    Funafuti
# Name: capital_city, dtype: object

# %%
#give me top 5 countries with highest democractic score

# %%
df.sort_values(by='democracy_score',ascending=False,inplace=True)

# %%
df.head()
# Out:
#          country         country_long            currency capital_city  \
# 127       Norway    Kingdom of Norway     Norwegian krone         Oslo
# 74       Iceland  Republic of Iceland       Iceland krona    Reykjavík
# 164       Sweden    Kingdom of Sweden       Swedish krona    Stockholm
# 122  New Zealand          New Zealand  New Zealand dollar   Wellington
# 46       Denmark   Kingdom of Denmark        Danish krone   Copenhagen
#
#                         region continent        demonym  latitude  longitude  \
# 127            Northern Europe    Europe      Norwegian      62.0       10.0
# 74             Northern Europe    Europe      Icelander      65.0      -18.0
# 164            Northern Europe    Europe        Swedish      62.0       15.0
# 122  Australia and New Zealand   Oceania  New Zealander     -41.0      174.0
# 46             Northern Europe    Europe         Danish      56.0       10.0
#
#      agricultural_land  ...  population  women_parliament_seats_pct  \
# 127            9859.62  ...     5457127                     44.9704
# 74            18720.00  ...      381900                     47.6190
# 164           30055.40  ...    10486941                     46.4183
# 122          101540.00  ...     5124100                     50.4202
# 46            26199.90  ...     5903037                     43.5754
#
#      rural_population  urban_population  press  democracy_score  \
# 127            891476           4565651  10.00             9.87
# 74              22945            358955   5.32             9.58
# 164           1206837           9280104   9.41             9.39
# 122            672077           4452023   7.27             9.26
# 46             686700           5216337   7.92             9.22
#
#      democracy_type  median_age     political_leader           title
# 127  Full democracy        35.6         Erna Solberg  Prime Minister
# 74   Full democracy        32.1  Katrín Jakobsdóttir  Prime Minister
# 164  Full democracy        35.6        Stefan Löfven  Prime Minister
# 122  Full democracy        32.8       Jacinda Ardern  Prime Minister
# 46   Full democracy        37.2    Mette Frederiksen  Prime Minister
#
# [5 rows x 64 columns]

# %%
#how many total regions are there
df['region'].value_counts()

# %%
df['region'].value_counts().count()
# Out:
# np.int64(22)

# %%
#how many countries lie in Eastern Europe regionabs
df[df['region']== 'Eastern Europe']['country']
# Out:
# 43      Czech Republic
# 151    Slovak Republic
# 24            Bulgaria
# 136             Poland
# 73             Hungary
# 139            Romania
# 111            Moldova
# 181            Ukraine
# 14             Belarus
# 140             Russia
# Name: country, dtype: object

# %%
#who is the politicla leader of the 2nd highest populated country
df.sort_values(by='population',ascending=False,inplace=True) #second highest 2 is China

# %%
df.loc[34]['political_leader']
# Out:
# 'Xi Jinping'

# %%
#how many countries are there whoes political leaders are unknown

# %%
df.loc[df['political_leader'].isna()]['country'].count()
# Out:
# np.int64(7)

# %%
#how many country have republic in their full name

# %%
df
# Out:
#            country                  country_long           currency  \
# 75           India             Republic of India       Indian rupee
# 34           China    People's Republic of China       Chinese yuan
# 184  United States      United States of America        U.S. dollar
# 76       Indonesia         Republic of Indonesia  Indonesian rupiah
# 129       Pakistan  Islamic Republic of Pakistan    Pakistani rupee
# ..             ...                           ...                ...
# 112         Monaco        Principality of Monaco               Euro
# 143     San Marino        Republic of San Marino               Euro
# 130          Palau             Republic of Palau        U.S. dollar
# 119          Nauru             Republic of Nauru  Australian dollar
# 179         Tuvalu                        Tuvalu  Australian dollar
#
#            capital_city              region continent      demonym   latitude  \
# 75            New Delhi       Southern Asia      Asia       Indian  20.000000
# 34              Beijing        Eastern Asia      Asia      Chinese  35.000000
# 184    Washington, D.C.    Northern America  Americas     American  38.000000
# 76              Jakarta  South-Eastern Asia      Asia   Indonesian  -5.000000
# 129           Islamabad       Southern Asia      Asia    Pakistani  30.000000
# ..                  ...                 ...       ...          ...        ...
# 112              Monaco      Western Europe    Europe   Monegasque  43.733333
# 143  City of San Marino     Southern Europe    Europe  Sammarinese  43.766667
# 130           Ngerulmud          Micronesia   Oceania      Palauan   7.500000
# 119               Yaren          Micronesia   Oceania      Nauruan  -0.533333
# 179            Funafuti           Polynesia   Oceania     Tuvaluan  -8.000000
#
#       longitude  agricultural_land  ...  population  \
# 75    77.000000          1790450.0  ...  1417173173
# 34   105.000000          5285080.0  ...  1412175000
# 184  -97.000000          4058100.0  ...   333287557
# 76   120.000000           623000.0  ...   275501339
# 129   70.000000           367230.0  ...   235824862
# ..          ...                ...  ...         ...
# 112    7.400000                NaN  ...       36469
# 143   12.416667               23.0  ...       33660
# 130  134.500000               43.0  ...       18055
# 119  166.916667                4.0  ...       12668
# 179  178.000000               18.0  ...       11312
#
#      women_parliament_seats_pct  rural_population  urban_population  press  \
# 75                      14.9446         908804812         508368361   1.71
# 34                      24.9412         514596570         897578430   0.99
# 184                     28.7037          56378923         276908634   3.04
# 76                      21.9130         115892393         159608946   2.13
# 129                     20.4678         146845783          88979079   1.71
# ..                          ...               ...               ...    ...
# 112                     33.3333                 0             36469   0.00
# 143                     33.3333               763             32897   0.00
# 130                      6.2500              3258             14797   0.00
# 119                     10.5263                 0             12668   0.00
# 179                      6.2500              3900              7412   0.00
#
#      democracy_score    democracy_type  median_age       political_leader  \
# 75              7.23  Flawed democracy        23.9          Narendra Modi
# 34              3.32     Authoritarian        34.5             Xi Jinping
# 184             7.96  Flawed democracy        33.9              Joe Biden
# 76              6.39  Flawed democracy        25.6            Joko Widodo
# 129             4.17     Hybrid regime        16.5             Imran Khan
# ..               ...               ...         ...                    ...
# 112             0.00           Unknown        50.5              Albert II
# 143             0.00           Unknown        42.7     Alessandro Mancini
# 130             0.00           Unknown        31.7  Thomas Remengesau Jr.
# 119             0.00           Unknown        16.3        Lionel Aingimea
# 179             0.00           Unknown        21.0          Kausea Natano
#
#                                         title
# 75                             Prime Minister
# 34   General Secretary of the Communist Party
# 184                                 President
# 76                                  President
# 129                            Prime Minister
# ..                                        ...
# 112                          Sovereign Prince
# 143                            Captain Regent
# 130                                 President
# 119                                 President
# 179                            Prime Minister
#
# [194 rows x 64 columns]

# %%
df.reset_index(inplace=True)

# %%
count = 0
def republic(txt):
    global count
    if 'republic' in txt.lower():
        count+=1
    
    return count

# %%
df['country_long'].apply(republic)
# Out:
# 0        1
# 1        2
# 2        2
# 3        3
# 4        4
#       ...
# 189    122
# 190    123
# 191    124
# 192    125
# 193    125
# Name: country_long, Length: 194, dtype: int64

# %%
#which country in african region has highest populationabs
africa =df[df['continent']=='Africa']

# %%
africa.head()
# Out:
#     index          country                             country_long  \
# 5     125          Nigeria              Federal Republic of Nigeria
# 11     57         Ethiopia  Federal Democratic Republic of Ethiopia
# 13     51            Egypt                   Arab Republic of Egypt
# 14     45  Dem. Rep. Congo         Democratic Republic of the Congo
# 22    168         Tanzania              United Republic of Tanzania
#
#               currency capital_city           region continent    demonym  \
# 5       Nigerian naira        Abuja   Western Africa    Africa   Nigerian
# 11      Ethiopian birr  Addis Ababa   Eastern Africa    Africa  Ethiopian
# 13      Egyptian pound        Cairo  Northern Africa    Africa   Egyptian
# 14     Congolese franc     Kinshasa    Middle Africa    Africa  Congolese
# 22  Tanzanian shilling       Dodoma   Eastern Africa    Africa  Tanzanian
#
#     latitude  longitude  ...  population  women_parliament_seats_pct  \
# 5       10.0        8.0  ...   218541212                     3.61111
# 11       8.0       38.0  ...   123379924                    41.48940
# 13      27.0       30.0  ...   110990103                    27.58040
# 14       0.0       25.0  ...    99010212                    12.80000
# 22      -6.0       35.0  ...    65497748                    36.85570
#
#     rural_population  urban_population  press  democracy_score  \
# 5          101575770         116965442   2.14             4.44
# 11          95420799          27959125   2.23             3.35
# 13          63300985          47689118   1.38             3.36
# 14          52636799          46373413   1.51             1.49
# 22          41471864          24025884   2.16             5.41
#
#     democracy_type  median_age      political_leader           title
# 5    Hybrid regime        13.2      Muhammadu Buhari       President
# 11   Authoritarian        14.7            Abiy Ahmed  Prime Minister
# 13   Authoritarian        20.1  Abdel Fattah el-Sisi       President
# 14   Authoritarian        11.7      Félix Tshisekedi       President
# 22   Hybrid regime        13.0         John Magufuli       President
#
# [5 rows x 65 columns]

# %%
# Out:
#    index  country                 country_long        currency capital_city  \
# 5    125  Nigeria  Federal Republic of Nigeria  Nigerian naira        Abuja
#
#            region continent   demonym  latitude  longitude  ...  population  \
# 5  Western Africa    Africa  Nigerian      10.0        8.0  ...   218541212
#
#    women_parliament_seats_pct  rural_population  urban_population  press  \
# 5                     3.61111         101575770         116965442   2.14
#
#    democracy_score  democracy_type  median_age  political_leader      title
# 5             4.44   Hybrid regime        13.2  Muhammadu Buhari  President
#
# [1 rows x 65 columns]
